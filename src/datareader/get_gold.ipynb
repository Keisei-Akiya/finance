# %% [markdown]
# # ゴールドの価格推移

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import pandas_datareader as pdr
from pandas_datareader import data
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns

# %%
start = datetime(1900, 1, 1)
end = datetime(2024, 12, 9)
df = data.DataReader('gold', 'stooq', start, end)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10033 entries, 2024-12-06 to 1985-02-04
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    10033 non-null  float64
#  1   High    10033 non-null  float64
#  2   Low     10033 non-null  float64
#  3   Close   10033 non-null  float64
#  4   Volume  10033 non-null  float64
# dtypes: float64(5)
# memory usage: 470.3 KB

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('1985-02-04 00:00:00'), Timestamp('2024-12-06 00:00:00'))

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=df['Close'], color='blue')
plt.title('金の価格推移 (1985/02/04 - 2024/12/06)')
plt.ylabel('価格($)')
plt.xlabel('日付')
plt.show()
